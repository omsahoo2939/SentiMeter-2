# %%
import joblib
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report

# Load the vectorizer and model from disk
print("Loading vectorizer and model...")
vectorizer = joblib.load('vectorizer.pkl')
model = joblib.load('sentiment_model.pkl')
print("Vectorizer and model loaded successfully.\n")

# Test cases for feedback (50 cases: positive and negative)
# Test cases for feedback (50 cases: positive and negative)
test_feedback = [
    "I love the product!",  # Positive
    "The service was excellent!",  # Positive
    "I hate the way I was treated.",  # Negative
    "Absolutely amazing experience.",  # Positive
    "This is the worst service I’ve ever used.",  # Negative
    "The product exceeded my expectations!",  # Positive
    "Terrible! I want a refund.",  # Negative
    "I am very happy with the service!",  # Positive
    "This is the worst experience ever.",  # Negative
    "The support team was helpful and quick.",  # Positive
    "I am dissatisfied with the quality of the product.",  # Negative
    "The customer support was great, they resolved my issue quickly.",  # Positive
    "I am not satisfied with the product I received.",  # Negative
    "Wonderful product, I highly recommend it!",  # Positive
    "The delivery took forever.",  # Negative
    "I had a great experience with the company.",  # Positive
    "I regret purchasing this product.",  # Negative
    "The team went above and beyond to help me.",  # Positive
    "This was a waste of money.",  # Negative
    "The quality is absolutely fantastic!",  # Positive
    "The staff was rude and unhelpful.",  # Negative
    "I will definitely buy again!",  # Positive
    "Not happy at all with the service.",  # Negative
    "The features are just what I needed.",  # Positive
    "Worst customer service experience ever.",  # Negative
    "Superb service, I’m really impressed.",  # Positive
    "The product was broken when it arrived.",  # Negative
    "I’m very impressed with how they handled the situation.",  # Positive
    "I will never recommend this to anyone.",  # Negative
    "This is exactly what I was looking for!",  # Positive
    "The packaging was a disaster.",  # Negative
    "Such a pleasant experience shopping here!",  # Positive
    "Horrible experience, the product doesn’t work.",  # Negative
    "It was delivered on time and in great condition.",  # Positive
    "It didn't meet my expectations.",  # Negative
    "Best decision I made all year.",  # Positive
    "Worst decision ever.",  # Negative
    "The team is very professional.",  # Positive
    "Unacceptable quality, very disappointed.",  # Negative
    "The product looks amazing.",  # Positive
    "Totally not worth the price.",  # Negative
    "Exceptional customer service.",  # Positive
    "I want my money back, this is awful.",  # Negative
    "I couldn’t be happier with my purchase.",  # Positive
    "I regret buying this.",  # Negative
    "Highly satisfied with the results.",  # Positive
    "The product doesn’t do what was promised.",  # Negative
    "Super fast delivery and great quality.",  # Positive
    "I was let down by the quality.",  # Negative
    "I am very happy with the work.",  # Positive  # Adjusted the last one to match the final label in y_true
]

# True labels for the test cases (positive or negative)
y_true = [
    'positive', 'positive', 'negative', 'positive', 'negative', 'positive', 
    'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 
    'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 
    'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 
    'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 
    'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 
    'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 
    'negative', 'positive', 'negative', 'positive', 'negative', 'positive', 
    'negative', 'positive'
]


# Convert the test feedback to a DataFrame
test_df = pd.DataFrame(test_feedback, columns=['feedback'])
print("Test feedback data:")
print(test_df)

# Vectorize the test feedback using the loaded vectorizer
print("\nVectorizing test feedback...")
X_test_feedback = vectorizer.transform(test_df['feedback'])
print("Test feedback vectorized.\n")

# Make predictions using the loaded model
print("Making predictions on test feedback...")
predicted_sentiment = model.predict(X_test_feedback)
print("Predictions completed.\n")

# Ensure the predicted sentiments length matches the true labels length
if len(predicted_sentiment) != len(y_true):
    print(f"Error: Mismatch in prediction and true labels count. Predicted: {len(predicted_sentiment)}, True: {len(y_true)}")
else:
    # Create a DataFrame to show feedback with predicted sentiment
    test_df['predicted_sentiment'] = predicted_sentiment
    print("Predicted sentiment for test feedback:")
    print(test_df)

    # Testing accuracy using the labeled dataset
    accuracy = accuracy_score(y_true, predicted_sentiment)
    print(f"\nTest Accuracy: {accuracy:.2f}")
    print("\nClassification Report:")
    print(classification_report(y_true, predicted_sentiment))

    # Check each prediction with its feedback
    for i, row in test_df.iterrows():
        print(f"Feedback: '{row['feedback']}' | Predicted Sentiment: {row['predicted_sentiment']} | True Sentiment: {y_true[i]}")
# Out:
# Loading vectorizer and model...
# Vectorizer and model loaded successfully.
#
# Test feedback data:
#                                              feedback
# 0                                 I love the product!
# 1                          The service was excellent!
# 2                       I hate the way I was treated.
# 3                      Absolutely amazing experience.
# 4           This is the worst service I’ve ever used.
# 5               The product exceeded my expectations!
# 6                          Terrible! I want a refund.
# 7                   I am very happy with the service!
# 8                  This is the worst experience ever.
# 9             The support team was helpful and quick.
# 10  I am dissatisfied with the quality of the prod...
# 11  The customer support was great, they resolved ...
# 12    I am not satisfied with the product I received.
# 13          Wonderful product, I highly recommend it!
# 14                         The delivery took forever.
# 15         I had a great experience with the company.
# 16                  I regret purchasing this product.
# 17         The team went above and beyond to help me.
# 18                         This was a waste of money.
# 19               The quality is absolutely fantastic!
# 20                  The staff was rude and unhelpful.
# 21                       I will definitely buy again!
# 22                 Not happy at all with the service.
# 23               The features are just what I needed.
# 24            Worst customer service experience ever.
# 25              Superb service, I’m really impressed.
# 26            The product was broken when it arrived.
# 27  I’m very impressed with how they handled the s...
# 28             I will never recommend this to anyone.
# 29            This is exactly what I was looking for!
# 30                      The packaging was a disaster.
# 31          Such a pleasant experience shopping here!
# 32     Horrible experience, the product doesn’t work.
# 33   It was delivered on time and in great condition.
# 34                    It didn't meet my expectations.
# 35                     Best decision I made all year.
# 36                               Worst decision ever.
# 37                     The team is very professional.
# 38           Unacceptable quality, very disappointed.
# 39                         The product looks amazing.
# 40                       Totally not worth the price.
# 41                      Exceptional customer service.
# 42               I want my money back, this is awful.
# 43            I couldn’t be happier with my purchase.
# 44                              I regret buying this.
# 45                 Highly satisfied with the results.
# 46          The product doesn’t do what was promised.
# 47             Super fast delivery and great quality.
# 48                     I was let down by the quality.
# 49                     I am very happy with the work.
#
# Vectorizing test feedback...
# Test feedback vectorized.
#
# Making predictions on test feedback...
# Predictions completed.
#
# Predicted sentiment for test feedback:
#                                              feedback predicted_sentiment
# 0                                 I love the product!            positive
# 1                          The service was excellent!            negative
# 2                       I hate the way I was treated.            negative
# 3                      Absolutely amazing experience.            positive
# 4           This is the worst service I’ve ever used.            negative
# 5               The product exceeded my expectations!            negative
# 6                          Terrible! I want a refund.            negative
# 7                   I am very happy with the service!            negative
# 8                  This is the worst experience ever.            negative
# 9             The support team was helpful and quick.            positive
# 10  I am dissatisfied with the quality of the prod...            negative
# 11  The customer support was great, they resolved ...            positive
# 12    I am not satisfied with the product I received.            negative
# 13          Wonderful product, I highly recommend it!            negative
# 14                         The delivery took forever.            negative
# 15         I had a great experience with the company.            positive
# 16                  I regret purchasing this product.            negative
# 17         The team went above and beyond to help me.            positive
# 18                         This was a waste of money.            negative
# 19               The quality is absolutely fantastic!            positive
# 20                  The staff was rude and unhelpful.            negative
# 21                       I will definitely buy again!            negative
# 22                 Not happy at all with the service.            negative
# 23               The features are just what I needed.            negative
# 24            Worst customer service experience ever.            negative
# 25              Superb service, I’m really impressed.            positive
# 26            The product was broken when it arrived.            negative
# 27  I’m very impressed with how they handled the s...            negative
# 28             I will never recommend this to anyone.            negative
# 29            This is exactly what I was looking for!            negative
# 30                      The packaging was a disaster.            negative
# 31          Such a pleasant experience shopping here!            negative
# 32     Horrible experience, the product doesn’t work.            positive
# 33   It was delivered on time and in great condition.            positive
# 34                    It didn't meet my expectations.            negative
# 35                     Best decision I made all year.            negative
# 36                               Worst decision ever.            negative
# 37                     The team is very professional.            positive
# 38           Unacceptable quality, very disappointed.            negative
# 39                         The product looks amazing.            positive
# 40                       Totally not worth the price.            negative
# 41                      Exceptional customer service.            positive
# 42               I want my money back, this is awful.            negative
# 43            I couldn’t be happier with my purchase.            negative
# 44                              I regret buying this.            negative
# 45                 Highly satisfied with the results.            negative
# 46          The product doesn’t do what was promised.            negative
# 47             Super fast delivery and great quality.            positive
# 48                     I was let down by the quality.            negative
# 49                     I am very happy with the work.            positive
#
# Test Accuracy: 0.74
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.66      0.96      0.78        24
#     positive       0.93      0.54      0.68        26
#
#     accuracy                           0.74        50
#    macro avg       0.80      0.75      0.73        50
# weighted avg       0.80      0.74      0.73        50
#
# Feedback: 'I love the product!' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'The service was excellent!' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'I hate the way I was treated.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'Absolutely amazing experience.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'This is the worst service I’ve ever used.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'The product exceeded my expectations!' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'Terrible! I want a refund.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'I am very happy with the service!' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'This is the worst experience ever.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'The support team was helpful and quick.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'I am dissatisfied with the quality of the product.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'The customer support was great, they resolved my issue quickly.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'I am not satisfied with the product I received.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'Wonderful product, I highly recommend it!' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'The delivery took forever.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'I had a great experience with the company.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'I regret purchasing this product.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'The team went above and beyond to help me.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'This was a waste of money.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'The quality is absolutely fantastic!' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'The staff was rude and unhelpful.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'I will definitely buy again!' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'Not happy at all with the service.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'The features are just what I needed.' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'Worst customer service experience ever.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'Superb service, I’m really impressed.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'The product was broken when it arrived.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'I’m very impressed with how they handled the situation.' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'I will never recommend this to anyone.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'This is exactly what I was looking for!' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'The packaging was a disaster.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'Such a pleasant experience shopping here!' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'Horrible experience, the product doesn’t work.' | Predicted Sentiment: positive | True Sentiment: negative
# Feedback: 'It was delivered on time and in great condition.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'It didn't meet my expectations.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'Best decision I made all year.' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'Worst decision ever.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'The team is very professional.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'Unacceptable quality, very disappointed.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'The product looks amazing.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'Totally not worth the price.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'Exceptional customer service.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'I want my money back, this is awful.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'I couldn’t be happier with my purchase.' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'I regret buying this.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'Highly satisfied with the results.' | Predicted Sentiment: negative | True Sentiment: positive
# Feedback: 'The product doesn’t do what was promised.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'Super fast delivery and great quality.' | Predicted Sentiment: positive | True Sentiment: positive
# Feedback: 'I was let down by the quality.' | Predicted Sentiment: negative | True Sentiment: negative
# Feedback: 'I am very happy with the work.' | Predicted Sentiment: positive | True Sentiment: positive
